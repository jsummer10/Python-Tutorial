# %% [markdown]
# # Testing

# %% [markdown]
# ## Pytest

# %%
# %%bash
# pytest test_pytest.py
# Out:
# ============================= test session starts ==============================
# platform darwin -- Python 3.14.2, pytest-9.0.3, pluggy-1.6.0
# rootdir: /Users/jacob/Code/Notes/Tutorials/Python-Tutorial/Lessons/02-Intermediate/08-Testing
# plugins: anyio-4.12.1, cov-7.1.0, shiny-1.6.1
# collected 15 items
#
# test_pytest.py ...............                                           [100%]
#
# ============================== 15 passed in 0.01s ==============================
